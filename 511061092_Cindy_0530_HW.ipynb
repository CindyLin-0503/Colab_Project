# %% [markdown]
# <a href="https://colab.research.google.com/github/CindyLin-0503/Colab_Project/blob/main/511061092_Cindy_0530_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
ls "/content/drive/MyDrive/Colab Notebooks/Scripts"
# Out:
# 'Emma Watson_Gender equality is your issue too.txt'  "Taylor Swift's NYU Commencement Speech.txt"
# 'Oprah Winfrey’s Golden Globes Speech.txt'

# %%
import nltk
nltk.download("popular")
nltk.download("all-corpora")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader

corpus_root = "/content/drive/MyDrive/Colab Notebooks/Scripts"
wordlists = PlaintextCorpusReader(corpus_root, ".*")

book = wordlists.fileids()
print(book)
# Out:
# ['Emma Watson_Gender equality is your issue too.txt', 'Oprah Winfrey’s Golden Globes Speech.txt', "Taylor Swift's NYU Commencement Speech.txt"]

# %%
import nltk
textText = wordlists.words('Oprah Winfrey’s Golden Globes Speech.txt')
single = nltk.text.Text(textText)
print(single)
# Out:
# <Text: Ah ! Thank you . Thank you all...>

# %%
import nltk
testText = wordlists.words( 'Oprah Winfrey’s Golden Globes Speech.txt')
single = nltk.text.Text(textText)

findList = ["a","the","can","people","I"]
single.dispersion_plot(findList)

# %%
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:7])
    for fileid in wordlists.fileids()
    for w in wordlists.words(fileid)
    for target in ["the","we","people"]
    if w.lower() == target)
cfd.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import nltk
from wordcloud import STOPWORDS

dataset = wordlists.raw('Oprah Winfrey’s Golden Globes Speech.txt')

tokens = dataset.split(' ')
clean_tokens = tokens[:]

for token in tokens:
   if token.lower() in STOPWORDS:
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)

freq.plot(20, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

file_text = open('/content/drive/MyDrive/Colab Notebooks/Scripts/Oprah Winfrey’s Golden Globes Speech.txt',"r").read()

temp = WordCloud(
    background_color="white",
    width=2000,
    height=1000,
    margin= 10,
).generate(file_text)

plt.imshow(temp)
plt.axis("off")
plt.show()

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {"she'd", 'than', 'down', 'such', 'there', "haven't", 'about', "didn't", "you'd", 'by', 'only', 'again', 'can', 'doing', 'as', 'once', 'those', 'you', 'yourself', 'that', 'all', 'shall', 'since', 'against', "he'll", 'who', 'com', 'hers', 'himself', 'not', 'why', 'me', 'themselves', 'between', 'few', 'over', "she'll", 'ever', 'however', "how's", "they're", 'other', 'an', 'nor', 'for', 'be', 'he', 'having', 'so', 'through', "why's", "hasn't", 'very', "couldn't", 'the', 'should', 'at', 'whom', 'their', "we'll", 'www', "you've", 'being', 'they', "they've", 'it', 'no', 'any', "when's", 'because', 'yours', 'were', 'and', 'of', "hadn't", 'most', "we'd", 'has', 'more', 'just', 'was', 'after', 'during', 'from', 'each', 'then', "don't", 'what', 'too', 'but', 'herself', "here's", "i've", 'she', 'where', 'cannot', "he'd", "shouldn't", 'i', "shan't", 'this', 'above', "i'd", "there's", "weren't", "i'm", "where's", 'or', 'are', "they'd", 'also', 'him', 'below', "isn't", 'like', "i'll", "who's", "wo
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

f = open('/content/drive/MyDrive/Colab Notebooks/Scripts/Oprah Winfrey’s Golden Globes Speech.txt',"r").read()

stop=["people","old people","time","life"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white",
    width=1500,
    height=1000,
    margin= 2,
    stopwords=stop
).generate(f)

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
